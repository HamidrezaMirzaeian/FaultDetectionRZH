# %% [markdown]
# # Load Data

# %% [markdown]
# # General Plots

# %% [markdown]
# # Define Metrics

# %% [markdown]
# # Train an Unsupervised Anomaly Detector

# %% [markdown]
# # Alarm Generation with Persistence Filter

# %% [markdown]
# # Plot Results
